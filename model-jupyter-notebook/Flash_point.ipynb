# %%
! pip install mesa
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
from mesa import Agent, Model

from mesa.space import MultiGrid

from mesa.time import RandomActivation

from mesa.datacollection import DataCollector

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
plt.rcParams["animation.html"] = "jshtml"
matplotlib.rcParams["animation.embed_limit"] = 2**128

import numpy as np

# %%
# Inicio
total_desease = 0
total_damage = 0
POI ={(2, 4): True, (5, 1): False, (5,8): True}
# Puerta abierta: True/False
puertas = {[0, 0, (1, 4, False), (1, 3, False), 0, 0, 0, 0],
		   [0, 0, 0, 0, (2, 6, False), (2, 5, False), 0, (3, 8, False)],
		   [0, (3, 3, False), (3, 2, False), 0, 0, 0, 0, (2, 8, False)],
		   [0, 0, 0, (5, 4, False), 0, (4, 7, False), (4, 6, False), 0],
		   [0, 0, 0, (4, 4, False), 0, 0, 0, 0],
		   [0, 0, 0, 0, (6, 6, False), (6, 5, False), (6, 8, False), (6, 7, False)]}

# construirEscenario() # Añadir orde extra y ajustar coordenadas
# colocarPOI()
# iniciarFuego()
# colocarPuertas()
# colocarEntradas()

# turno()
# 	AP += 4

# distance_between_2_points() #Fórmula matemática entre 2 coordenadas

# exit_firefighter(coordenates):
# move(minimum(distance_between_2_points(entrance1, coordenates),
# 		   distance_between_2_points(entrance2, coordenates),
# 		   distance_between_2_points(entrance3, coordenates),
# 		   distance_between_2_points(entrance4, coordenates))
	
	
# existence_POI(coordenates):
# 	if(hay POI en coordenates):
# if POI == victim:
# 			total_desease ++
# 		replace_POI()

# existence_Firefighter(coordenates):
# 	if(hay bomberos en coordenates):
# 		exit_firefighter()

# shockwaveDMG()

# explotion(coordenates):
# 	actual = coordenates
# 	forward = True
# while(forward): #up
# 	if not (existence_fire(actual[1]+=1])): # Sumar 1 en y para ir arriba
# 		shockwaveDMG()
# 		forward = False
		
# actual = coordenates
# forward = True
# while(forward): #up
# 	if not (existence_fire(actual[1]-=1])): # Sumar 1 en y para ir abajo
# 		shockwaveDMG()
# 		forward = False
# actual = coordenates
# forward = True
# while(forward): #up
# 	if not (existence_fire(actual[0]+=1])): # Sumar 1 en y para ir a la derecha
# 		shockwaveDMG()
# 		forward = False
# actual = coordenates
# forward = True
# while(forward): #up
# 	if not (existence_fire(actual[0]-=1])): # Sumar 1 en y para ir a la izquierda
# 		shockwaveDMG()
# 		forward = False
	

# colocate_Fire())
# 	verifyContent(){
# 		if(vacío):
# 			humo
# 		if(humo):
# 			fuego
# 			existence_POI()
# 			existence_Firefighter()	
# 		if(fuego):
# 			explotion()

# update()
# 	adyacentSmoke_to_Fire() #Flip smokes to fire
# 	explotion
